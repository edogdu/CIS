# %% [markdown]
# # Physical Data Analysis

# %% [markdown]
# ## What does our dataset look like?

# %% [markdown]
# ### First, what does the data look like?

# %%
import pandas as pd
import os
pd.set_option('display.max_columns', None)
pd.set_option('display.max_info_columns', 9999)


phys_data_path = '../data/testbed_system_1/Physical'

df = pd.concat((pd.read_csv(os.path.join(phys_data_path, f), sep='\t') for f in os.listdir(phys_data_path) if f.endswith('.csv')), ignore_index=True)

print(df.head())
# Out:
#                   Time  Tank_1  Tank_2  Tank_3  Tank_4  Tank_5  Tank_6  \
# 0  09/04/2021 18:23:28       0       0       0       0       0       0
# 1  09/04/2021 18:23:29       0       0       0       0       0       0
# 2  09/04/2021 18:23:30       0       0       0       0       0       0
# 3  09/04/2021 18:23:31       0       0       0       0       0       0
# 4  09/04/2021 18:23:32       0       0       0       0       0       0
#
#    Tank_7  Tank_8  Pump_1  Pump_2  Pump_3  Pump_4  Pump_5  Pump_6  \
# 0       0       0   False   False   False   False   False   False
# 1       0       0   False   False   False   False   False   False
# 2       0       0   False   False   False   False   False   False
# 3       0       0   False   False   False   False   False   False
# 4       0       0    True    True   False   False   False   False
#
#    Flow_sensor_1  Flow_sensor_2  Flow_sensor_3  Flow_sensor_4  Valv_1  Valv_2  \
# ...

# %% [markdown]
# ### Results

# %% [markdown]
# ### What type of data are we working with?

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10923 entries, 0 to 10922
# Data columns (total 44 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           10923 non-null  object
#  1   Tank_1         10923 non-null  int64
#  2   Tank_2         10923 non-null  int64
#  3   Tank_3         10923 non-null  int64
#  4   Tank_4         10923 non-null  int64
#  5   Tank_5         10923 non-null  int64
#  6   Tank_6         10923 non-null  int64
#  7   Tank_7         10923 non-null  int64
#  8   Tank_8         10923 non-null  int64
#  9   Pump_1         10923 non-null  bool
#  10  Pump_2         10923 non-null  bool
#  11  Pump_3         10923 non-null  bool
#  12  Pump_4         10923 non-null  bool
#  13  Pump_5         10923 non-null  bool
#  14  Pump_6         10923 non-null  bool
#  15  Flow_sensor_1  10923 non-null  int64
#  16  Flow_sensor_2  10923 non-null  int64
#  17  Flow_sensor_3  10923 non-null  int64
# ...

# %% [markdown]
# ### Results

# %% [markdown]
# ### Do we have any columns with NULL/NaN values?

# %%
print(df.columns[df.isna().any()].tolist())

print(df.isna().sum())
# Out:
# ['Label_n', 'Lable_n']
# Time                0
# Tank_1              0
# Tank_2              0
# Tank_3              0
# Tank_4              0
# Tank_5              0
# Tank_6              0
# Tank_7              0
# Tank_8              0
# Pump_1              0
# Pump_2              0
# Pump_3              0
# Pump_4              0
# Pump_5              0
# Pump_6              0
# Flow_sensor_1       0
# Flow_sensor_2       0
# Flow_sensor_3       0
# Flow_sensor_4       0
# Valv_1              0
# Valv_2              0
# Valv_3              0
# Valv_4              0
# Valv_5              0
# Valv_6              0
# Valv_7              0
# Valv_8              0
# Valv_9              0
# Valv_10             0
# Valv_11             0
# Valv_12             0
# Valv_13             0
# Valv_14             0
# Valv_15             0
# Valv_16             0
# Valv_17             0
# Valv_18             0
# Valv_19             0
# Valv_20             0
# Valv_21             0
# ...

# %% [markdown]
# ### Results
# Why are there label_n and lable_n?  Shows up on our null list.

# %% [markdown]
# ### How many use cases do we have of each type of attack?

# %%
df['Label'].value_counts()
# Out:
# Label
# normal            8657
# MITM              1008
# physical fault     685
# DoS                310
# nomal              249
# scan                14
# Name: count, dtype: int64

# %% [markdown]
# ### Results
# Anything we need to consider?  How can we handle any inbalance?

# %% [markdown]
# ### Are there any outliers?
